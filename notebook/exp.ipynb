# %% [markdown]
# https://stats.stackexchange.com/questions/453540/how-does-lightgbm-deals-with-incremental-learning-and-concept-drift
#
# 1. LightGBM will add more trees if we update it through continued training (e.g. through BoosterUpdateOneIter). Assuming we use refit we will be using existing tree structures to update the output of the leaves based on the new data. It is faster than re-training from scratch, since we do not have to re-discover the optimal tree structures. Nevertheless, please note that almost certainly it will have worse performance (on the combined old and new data) than doing a full retrain from scratch on them.
# 2. Any online learning algorithm will be designed to adapt to changes. That said, LighyGBM's performance will depend on the training parameters we will use and how we will validate our predictions (e.g. how much we care to disregard previous data points). Assuming we properly train our booster, without having a relevant baseline (e.g. a ridge regression trained on an incremental manner) it does not make sense to say "LightGBM is good (or bad)" for dealing with concept drift.

# %%
import os

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statistics

import lightgbm as lgb

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
# Out:
# /Users/masafumi/anaconda3/envs/py37/lib/python3.7/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
INPUT_PATH = '../data/input'

# %%
def read_data(year):
    df = pd.read_csv(os.path.join(INPUT_PATH, f'juyo-{year}.txt'),  skiprows=1, encoding='shift-jis')
    df_temp = pd.read_csv(os.path.join(INPUT_PATH, f'temp-{year}.csv'),  skiprows=3, encoding='shift-jis')
    df_precipitation = pd.read_csv(os.path.join(INPUT_PATH, f'precipitation-{year}.csv'),  skiprows=3, encoding='shift-jis')
    df['DATE_TIME'] = df['DATE'] + ' ' + df['TIME'] 
    df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])
    df = df.rename(columns={'実績(万kW)': 'usage'})
    df['temperature'] = df_temp['気温(℃)']
    df['precipitation'] = df_precipitation['降水量(mm)']
    return df


def preprocess(df):
    df['month'] = df['DATE_TIME'].dt.month
    df['hour'] = df['DATE_TIME'].dt.hour
    df['minute'] = df['DATE_TIME'].dt.minute
    df['dayofweek'] = df['DATE_TIME'].dt.dayofweek
    df = df.drop(['DATE', 'TIME', 'DATE_TIME'], axis=1)
    return df


def make_dataset(X, y):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_valid = lgb.Dataset(X_valid, y_valid)
    
    return lgb_train, lgb_valid


def train_model(lgb_train, lgb_valid, init_model=None):
    params = {
        'objective': 'rmse',
        'learning_rate': 0.01, 
        'num_leaves': 31, 
        'importance_type': 'gain',
    }

    model = lgb.train(params, lgb_train, num_boost_round=10000,
                      valid_sets=lgb_valid, verbose_eval=100, early_stopping_rounds=100,
                      init_model=init_model)
    return model


def train_cv(X, y):
    n_splits = 5
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=0)

    scores_tmp = []
    for train_index, valid_index in kf.split(X, y):
        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

        lgb_train = lgb.Dataset(X_train, y_train)
        lgb_valid = lgb.Dataset(X_valid, y_valid)

        model = train_model(lgb_train, lgb_valid)
        y_pred = model.predict(X_test,  num_iteration=model.best_iteration)
        scores_tmp.append(mean_squared_error(y_test, y_pred, squared=False))
    return np.mean(scores_tmp), np.std(scores_tmp)


# def plot_pred(y_test, y_pred):
#     plt.figure(figsize=(5,5))
#     plt.plot(y_test, y_pred, '.')
#     plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '-')
    
#     print(mean_squared_error(y_test, y_pred, squared=False))

# %% [markdown]
# ## データ読み込み

# %%
df_2017 = preprocess(read_data(2017))
df_2018 = preprocess(read_data(2018))
df_2019 = preprocess(read_data(2019))

# %%
X_test = df_2019.drop('usage', axis=1)
y_test = df_2019['usage'].astype('float32')

# %%
scores = {}

# %% [markdown]
# ## パターン1

# %% [markdown]
# 2017年のデータで学習し、2019年のデータを予測する。

# %%
X = df_2017.drop('usage', axis=1)
y = df_2017['usage'].astype('float32')

# %%
scores['pattern1'] = train_cv(X, y)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 308.139
# [200]	valid_0's rmse: 207.618
# [300]	valid_0's rmse: 175.461
# [400]	valid_0's rmse: 163.172
# [500]	valid_0's rmse: 157.354
# [600]	valid_0's rmse: 154.202
# [700]	valid_0's rmse: 152.705
# [800]	valid_0's rmse: 152.109
# [900]	valid_0's rmse: 151.428
# [1000]	valid_0's rmse: 150.978
# [1100]	valid_0's rmse: 150.495
# [1200]	valid_0's rmse: 150.228
# [1300]	valid_0's rmse: 149.623
# [1400]	valid_0's rmse: 149.291
# [1500]	valid_0's rmse: 149.011
# [1600]	valid_0's rmse: 148.84
# [1700]	valid_0's rmse: 148.703
# [1800]	valid_0's rmse: 148.511
# [1900]	valid_0's rmse: 148.38
# [2000]	valid_0's rmse: 148.214
# [2100]	valid_0's rmse: 148.147
# [2200]	valid_0's rmse: 148.107
# [2300]	valid_0's rmse: 148.026
# [2400]	valid_0's rmse: 148.028
# Early stopping, best iteration is:
# [2343]	valid_0's rmse: 147.994
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 308.044
# [200]	valid_0's rmse: 208.728
# [300]	valid_0's rmse: 174.349
# [400]	valid_0's rmse: 160.774
# [500]	valid_0's rmse: 154.046
# [600]	valid_0's rmse: 150.857
# [700]	valid_0's rmse: 149.243
# [800]	valid_0's rmse: 147.96
# [900]	valid_0's rmse: 147.011
# [1000]	valid_0's rmse: 146.534
# [1100]	valid_0's rmse: 145.856
# [1200]	valid_0's rmse: 145.389
# [1300]	valid_0's rmse: 144.966
# [1400]	valid_0's rmse: 144.67
# [1500]	valid_0's rmse: 144.226
# [1600]	valid_0's rmse: 143.999
# [1700]	valid_0's rmse: 143.739
# [1800]	valid_0's rmse: 143.632
# [1900]	valid_0's rmse: 143.549
# [2000]	valid_0's rmse: 143.444
# [2100]	valid_0's rmse: 143.388
# [2200]	valid_0's rmse: 143.225
# [2300]	valid_0's rmse: 143.143
# [2400]	valid_0's rmse: 143.052
# [2500]	valid_0's rmse: 142.973
# [2600]	valid_0's rmse: 142.852
# [2700]	valid_0's rmse: 142.79
# [2800]	valid_0's rmse: 142.712
# [2900]	valid_0's rmse: 142.644
# [3000]	valid_0's rmse: 142.689
# Early stopping, best iteration is:
# [2932]	valid_0's rmse: 142.618
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 307.236
# [200]	valid_0's rmse: 206.505
# [300]	valid_0's rmse: 172.497
# [400]	valid_0's rmse: 159.18
# [500]	valid_0's rmse: 152.995
# [600]	valid_0's rmse: 149.517
# [700]	valid_0's rmse: 147.103
# [800]	valid_0's rmse: 146.112
# [900]	valid_0's rmse: 145.617
# [1000]	valid_0's rmse: 145.007
# [1100]	valid_0's rmse: 144.111
# [1200]	valid_0's rmse: 143.165
# [1300]	valid_0's rmse: 142.773
# [1400]	valid_0's rmse: 142.255
# [1500]	valid_0's rmse: 142.018
# [1600]	valid_0's rmse: 141.856
# [1700]	valid_0's rmse: 141.658
# [1800]	valid_0's rmse: 141.54
# [1900]	valid_0's rmse: 141.539
# Early stopping, best iteration is:
# [1831]	valid_0's rmse: 141.509
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 307.588
# [200]	valid_0's rmse: 205.717
# [300]	valid_0's rmse: 173.923
# [400]	valid_0's rmse: 162.082
# [500]	valid_0's rmse: 156.049
# [600]	valid_0's rmse: 152.561
# [700]	valid_0's rmse: 150.92
# [800]	valid_0's rmse: 150.25
# [900]	valid_0's rmse: 149.368
# [1000]	valid_0's rmse: 148.918
# [1100]	valid_0's rmse: 148.491
# [1200]	valid_0's rmse: 148.034
# [1300]	valid_0's rmse: 147.761
# [1400]	valid_0's rmse: 147.557
# [1500]	valid_0's rmse: 147.27
# [1600]	valid_0's rmse: 147.221
# [1700]	valid_0's rmse: 147.031
# [1800]	valid_0's rmse: 146.829
# [1900]	valid_0's rmse: 146.833
# [2000]	valid_0's rmse: 146.696
# [2100]	valid_0's rmse: 146.613
# [2200]	valid_0's rmse: 146.422
# [2300]	valid_0's rmse: 145.992
# [2400]	valid_0's rmse: 145.852
# [2500]	valid_0's rmse: 145.812
# [2600]	valid_0's rmse: 145.641
# [2700]	valid_0's rmse: 145.703
# Early stopping, best iteration is:
# [2609]	valid_0's rmse: 145.62
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 306.35
# [200]	valid_0's rmse: 207.178
# [300]	valid_0's rmse: 175.687
# [400]	valid_0's rmse: 164.633
# [500]	valid_0's rmse: 158.497
# [600]	valid_0's rmse: 154.831
# [700]	valid_0's rmse: 152.983
# [800]	valid_0's rmse: 152.104
# [900]	valid_0's rmse: 151.553
# [1000]	valid_0's rmse: 151.072
# [1100]	valid_0's rmse: 150.863
# [1200]	valid_0's rmse: 150.671
# [1300]	valid_0's rmse: 150.478
# [1400]	valid_0's rmse: 150.285
# [1500]	valid_0's rmse: 150.037
# [1600]	valid_0's rmse: 149.848
# [1700]	valid_0's rmse: 149.883
# Early stopping, best iteration is:
# [1601]	valid_0's rmse: 149.845

# %% [markdown]
# ## パターン2

# %% [markdown]
# 2018年のデータで学習し、2019年のデータを予測する。

# %%
X = df_2018.drop('usage', axis=1)
y = df_2018['usage'].astype('float32')

# %%
scores['pattern2'] = train_cv(X, y)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 338.023
# [200]	valid_0's rmse: 232.876
# [300]	valid_0's rmse: 200.769
# [400]	valid_0's rmse: 188.154
# [500]	valid_0's rmse: 180.745
# [600]	valid_0's rmse: 177.393
# [700]	valid_0's rmse: 175.052
# [800]	valid_0's rmse: 173.527
# [900]	valid_0's rmse: 172.495
# [1000]	valid_0's rmse: 171.974
# [1100]	valid_0's rmse: 171.086
# [1200]	valid_0's rmse: 170.417
# [1300]	valid_0's rmse: 170.088
# [1400]	valid_0's rmse: 169.832
# [1500]	valid_0's rmse: 169.724
# Early stopping, best iteration is:
# [1470]	valid_0's rmse: 169.677
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse:
# [1900]	valid_0's rmse: 173.074
# [2000]	valid_0's rmse: 172.984
# [2100]	valid_0's rmse: 173.08
# Early stopping, best iteration is:
# [2023]	valid_0's rmse: 172.958

# %% [markdown]
# ## パターン3

# %% [markdown]
# 2017年と2018年のデータで学習して2019年のデータを予測する。

# %%
X = pd.concat([df_2017, df_2018], sort=False).drop('usage', axis=1)
y = pd.concat([df_2017, df_2018], sort=False)['usage'].astype('float32')

# %%
scores['pattern3'] = train_cv(X, y)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 329.215
# [200]	valid_0's rmse: 225.715
# [300]	valid_0's rmse: 192.11
# [400]	valid_0's rmse: 179.773
# [500]	valid_0's rmse: 173.602
# [600]	valid_0's rmse: 170.316
# [700]	valid_0's rmse: 168.552
# [800]	valid_0's rmse: 167.664
# [900]	valid_0's rmse: 167.044
# [1000]	valid_0's rmse: 166.525
# [1100]	valid_0's rmse: 166.097
# [1200]	valid_0's rmse: 165.854
# [1300]	valid_0's rmse: 165.521
# [1400]	valid_0's rmse: 165.371
# [1500]	valid_0's rmse: 165.077
# [1600]	valid_0's rmse: 164.73
# [1700]	valid_0's rmse: 164.386
# [1800]	valid_0's rmse: 164.064
# [1900]	valid_0's rmse: 163.813
# [2000]	valid_0's rmse: 163.589
# [2100]	valid_0's rmse: 163.437
# [2200]	valid_0's rmse: 163.184
# [2300]	valid_0's rmse: 163.062
# Early stopping, best iteration is:
# [2289]	valid_0's rmse: 163.054
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 328.708
# [200]	valid_0's rmse: 224.475
# [300]	valid_0's rmse: 190.165
# [400]	valid_0's rmse: 176.656
# [500]	valid_0's rmse: 170.91
# [600]	valid_0's rmse: 167.74
# [700]	valid_0's rmse: 165.891
# [800]	valid_0's rmse: 164.522
# [900]	valid_0's rmse: 163.765
# [1000]	valid_0's rmse: 163.047
# [1100]	valid_0's rmse: 162.561
# [1200]	valid_0's rmse: 162.091
# [1300]	valid_0's rmse: 161.705
# [1400]	valid_0's rmse: 161.621
# [1500]	valid_0's rmse: 161.508
# [1600]	valid_0's rmse: 161.407
# [1700]	valid_0's rmse: 161.214
# [1800]	valid_0's rmse: 161.1
# [1900]	valid_0's rmse: 160.779
# [2000]	valid_0's rmse: 160.557
# [2100]	valid_0's rmse: 160.488
# [2200]	valid_0's rmse: 160.432
# [2300]	valid_0's rmse: 160.432
# Early stopping, best iteration is:
# [2240]	valid_0's rmse: 160.39
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 324.791
# [200]	valid_0's rmse: 220.347
# [300]	valid_0's rmse: 186.06
# [400]	valid_0's rmse: 173.631
# [500]	valid_0's rmse: 168.165
# [600]	valid_0's rmse: 165.608
# [700]	valid_0's rmse: 164.148
# [800]	valid_0's rmse: 163.163
# [900]	valid_0's rmse: 162.612
# [1000]	valid_0's rmse: 162.299
# [1100]	valid_0's rmse: 162.124
# [1200]	valid_0's rmse: 162.07
# [1300]	valid_0's rmse: 162.01
# [1400]	valid_0's rmse: 161.82
# [1500]	valid_0's rmse: 161.627
# [1600]	valid_0's rmse: 161.386
# [1700]	valid_0's rmse: 161.381
# Early stopping, best iteration is:
# [1637]	valid_0's rmse: 161.326
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 334.286
# [200]	valid_0's rmse: 234.574
# [300]	valid_0's rmse: 203.251
# [400]	valid_0's rmse: 191.093
# [500]	valid_0's rmse: 185.272
# [600]	valid_0's rmse: 182.195
# [700]	valid_0's rmse: 180.284
# [800]	valid_0's rmse: 178.986
# [900]	valid_0's rmse: 178.179
# [1000]	valid_0's rmse: 177.666
# [1100]	valid_0's rmse: 177.232
# [1200]	valid_0's rmse: 176.706
# [1300]	valid_0's rmse: 176.427
# [1400]	valid_0's rmse: 176.35
# [1500]	valid_0's rmse: 176.28
# [1600]	valid_0's rmse: 176.065
# [1700]	valid_0's rmse: 175.803
# [1800]	valid_0's rmse: 175.615
# [1900]	valid_0's rmse: 175.501
# [2000]	valid_0's rmse: 175.181
# [2100]	valid_0's rmse: 175.152
# Early stopping, best iteration is:
# [2055]	valid_0's rmse: 175.081
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 326.949
# [200]	valid_0's rmse: 225.415
# [300]	valid_0's rmse: 193.393
# [400]	valid_0's rmse: 180.433
# [500]	valid_0's rmse: 174.35
# [600]	valid_0's rmse: 171.476
# [700]	valid_0's rmse: 169.749
# [800]	valid_0's rmse: 168.823
# [900]	valid_0's rmse: 168.317
# [1000]	valid_0's rmse: 168.184
# [1100]	valid_0's rmse: 167.977
# [1200]	valid_0's rmse: 167.704
# [1300]	valid_0's rmse: 167.462
# [1400]	valid_0's rmse: 167.142
# [1500]	valid_0's rmse: 166.905
# [1600]	valid_0's rmse: 166.687
# [1700]	valid_0's rmse: 166.531
# [1800]	valid_0's rmse: 166.312
# [1900]	valid_0's rmse: 166.137
# [2000]	valid_0's rmse: 166.041
# [2100]	valid_0's rmse: 165.875
# [2200]	valid_0's rmse: 165.668
# [2300]	valid_0's rmse: 165.535
# [2400]	valid_0's rmse: 165.478
# [2500]	valid_0's rmse: 165.433
# [2600]	valid_0's rmse: 165.376
# [2700]	valid_0's rmse: 165.271
# [2800]	valid_0's rmse: 165.133
# [2900]	valid_0's rmse: 165.077
# Early stopping, best iteration is:
# [2861]	valid_0's rmse: 165.051

# %% [markdown]
# ## パターン4

# %% [markdown]
# 2017年のデータで学習し、2018年のデータで追加学習して2019年のデータを予測する。

# %%
X = df_2017.drop('usage', axis=1)
y = df_2017['usage'].astype('float32')

X2= df_2018.drop('usage', axis=1)
y2 = df_2018['usage'].astype('float32')

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=0)

scores_tmp = []
for train_index, valid_index in kf.split(X, y):
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
    
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_valid = lgb.Dataset(X_valid, y_valid)

    model = train_model(lgb_train, lgb_valid)
    
    X2_train, X2_valid = X2.iloc[train_index], X2.iloc[valid_index]
    y2_train, y2_valid = y2.iloc[train_index], y2.iloc[valid_index]
    
    lgb_train2 = lgb.Dataset(X2_train, y2_train)
    lgb_valid2 = lgb.Dataset(X2_valid, y2_valid)
    
    model2 = train_model(lgb_train2, lgb_valid2, init_model=model)

    y_pred = model2.predict(X_test,  num_iteration=model2.best_iteration)
    scores_tmp.append(mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse:
# Early stopping, best iteration is:
# [2609]	valid_0's rmse: 145.62
# Training until validation scores don't improve for 100 rounds
# [2700]	valid_0's rmse: 186.022
# [2800]	valid_0's rmse: 179.152
# [2900]	valid_0's rmse: 176.305
# [3000]	valid_0's rmse: 174.851
# [3100]	valid_0's rmse: 173.914
# [3200]	valid_0's rmse: 172.904
# [3300]	valid_0's rmse: 172.441
# [3400]	valid_0's rmse: 172.021
# [3500]	valid_0's rmse: 171.618
# [3600]	valid_0's rmse: 171.218
# [3700]	valid_0's rmse: 170.715
# [3800]	valid_0's rmse: 170.603
# Early stopping, best iteration is:
# [3797]	valid_0's rmse: 170.594
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 306.35
# [200]	valid_0's rmse: 207.178
# [300]	valid_0's rmse: 175.687
# [400]	valid_0's rmse: 164.633
# [500]	valid_0's rmse: 158.497
# [600]	valid_0's rmse: 154.831
# [700]	valid_0's rmse: 152.983
# [800]	valid_0's rmse: 152.104
# [900]	valid_0's rmse: 151.553
# [1000]	valid_0's rmse: 151.072
# [1100]	valid_0's rmse: 150.863
# [1200]	valid_0's rmse: 150.671
# [1300]	valid_0's rmse: 150.478
# [1400]	valid_0's rmse: 150.285
# [1500]	valid_0's rmse: 150.037
# [1600]	valid_0's rmse: 149.848
# [1700]	valid_0's rmse: 149.883
# Early stopping, best iteration is:
# [1601]	valid_0's rmse: 149.845
# Training until validation scores don't improve for 100 rounds
# [1700]	valid_0's rmse: 199.59
# [1800]	valid_0's rmse: 190.929
# [1900]	valid_0's rmse: 187.04
# [2000]	valid_0's rmse: 184.397
# [2100]	valid_0's rmse: 182.365
# [2200]	valid_0's rmse: 180.972
# [2300]	valid_0's rmse: 179.89
# [2400]	valid_0's rmse: 179.446
# [2500]	valid_0's rmse: 178.894
# [2600]	valid_0's rmse: 178.472
# [2700]	valid_0's rmse: 178.121
# [2800]	valid_0's rmse: 177.694
# [2900]	valid_0's rmse: 177.409
# [3000]	valid_0's rmse: 177.125
# [3100]	valid_0's rmse: 177.221
# Early stopping, best iteration is:
# [3000]	valid_0's rmse: 177.125

# %%
scores['pattern4'] = np.mean(scores_tmp), np.std(scores_tmp)

# %% [markdown]
# ## パターン5

# %% [markdown]
# 2017年のデータで学習し、ツリー構造は変えずに2018年のデータで葉の重みを修正して2019年のデータを予測する。

# %%
X = df_2017.drop('usage', axis=1)
y = df_2017['usage'].astype('float32')

X2= df_2018.drop('usage', axis=1)
y2 = df_2018['usage'].astype('float32')

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=0)

scores_tmp = []
for train_index, valid_index in kf.split(X, y):
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
    
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_valid = lgb.Dataset(X_valid, y_valid)

    model = train_model(lgb_train, lgb_valid)    
    model2 = model.refit(X2, y2, decay_rate=0.9)

    y_pred = model2.predict(X_test,  num_iteration=model2.best_iteration)
    scores_tmp.append(mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 307.588
# [200]	valid_0's rmse: 205.717
# [300]	valid_0's rmse: 173.923
# [400]	valid_0's rmse: 162.082
# [500]	valid_0's rmse: 156.049
# [600]	valid_0's rmse: 152.561
# [700]	valid_0's rmse: 150.92
# [800]	valid_0's rmse: 150.25
# [900]	valid_0's rmse: 149.368
# [1000]	valid_0's rmse: 148.918
# [1100]	valid_0's rmse: 148.491
# [1200]	valid_0's rmse: 148.034
# [1300]	valid_0's rmse: 147.761
# [1400]	valid_0's rmse: 147.557
# [1500]	valid_0's rmse: 147.27
# [1600]	valid_0's rmse: 147.221
# [1700]	valid_0's rmse: 147.031
# [1800]	valid_0's rmse: 146.829
# [1900]	valid_0's rmse: 146.833
# [2000]	valid_0's rmse: 146.696
# [2100]	valid_0's rmse: 146.613
# [2200]	valid_0's rmse: 146.422
# [2300]	valid_0's rmse: 145.992
# [2400]	valid_0's rmse: 145.852
# [2500]	valid_0's rmse: 145.812
# [2600]	valid_0's rmse: 145.641
# [2700]	valid_0's rmse: 145.703
# Early stopping, best iteration is:
# [2609]	valid_0's rmse: 145.62
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 306.35
# [200]	valid_0's rmse: 207.178
# [300]	valid_0's rmse: 175.687
# [400]	valid_0's rmse: 164.633
# [500]	valid_0's rmse: 158.497
# [600]	valid_0's rmse: 154.831
# [700]	valid_0's rmse: 152.983
# [800]	valid_0's rmse: 152.104
# [900]	valid_0's rmse: 151.553
# [1000]	valid_0's rmse: 151.072
# [1100]	valid_0's rmse: 150.863
# [1200]	valid_0's rmse: 150.671
# [1300]	valid_0's rmse: 150.478
# [1400]	valid_0's rmse: 150.285
# [1500]	valid_0's rmse: 150.037
# [1600]	valid_0's rmse: 149.848
# [1700]	valid_0's rmse: 149.883
# Early stopping, best iteration is:
# [1601]	valid_0's rmse: 149.845

# %%
scores['pattern5'] = np.mean(scores_tmp), np.std(scores_tmp)

# %% [markdown]
# ## スコア一覧

# %%
print('{:.2f}'.format(scores['pattern1'][0]), '{:.2f}'.format(scores['pattern1'][1]), '--', '2017年のデータで学習し、2019年のデータを予測する。')
print('{:.2f}'.format(scores['pattern2'][0]), '{:.2f}'.format(scores['pattern2'][1]), '--', '2018年のデータで学習し、2019年のデータを予測する。')
print('{:.2f}'.format(scores['pattern3'][0]), '{:.2f}'.format(scores['pattern3'][1]), '--', '2017年と2018年のデータで学習して2019年のデータを予測する。')
print('{:.2f}'.format(scores['pattern4'][0]), '{:.2f}'.format(scores['pattern4'][1]), '--', '2017年のデータで学習し、2018年のデータで追加学習して2019年のデータを予測する。')
print('{:.2f}'.format(scores['pattern5'][0]), '{:.2f}'.format(scores['pattern5'][1]), '--', '2017年のデータで学習し、ツリー構造は変えずに2018年のデータで葉の重みを修正して2019年のデータを予測する。')
# Out:
# 209.78 0.83 -- 2017年のデータで学習し、2019年のデータを予測する。
# 215.33 2.54 -- 2018年のデータで学習し、2019年のデータを予測する。
# 205.51 0.91 -- 2017年と2018年のデータで学習して2019年のデータを予測する。
# 217.77 1.73 -- 2017年のデータで学習し、2018年のデータで追加学習して2019年のデータを予測する。
# 211.20 0.81 -- 2017年のデータで学習し、ツリー構造は変えずに2018年のデータで葉の重みを修正して2019年のデータを予測する。
